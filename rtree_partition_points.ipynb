# %% [markdown]
# <a href="https://colab.research.google.com/github/cdrowley/notebook-demos/blob/main/rtree_partition_points.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup

# %%
# !pip install folium matplotlib mapclassify rtree --quiet

# %%
import geopandas as gpd
import numpy as np

from shapely.geometry import box, Point

from rtree import index

# %% [markdown]
# ## Generate Fake Points

# %%
# bounding box around Denmark
minx, miny = 8.0, 54.5
maxx, maxy = 12.65, 57.75
num_points = 10_000

# generate points
x_coords = np.random.uniform(minx, maxx, num_points)
y_coords = np.random.uniform(miny, maxy, num_points)

# random locations to mimic dense urban areas
city_centers = [(9.0, 55.0), (10.5, 56.0), (11.0, 55.5)]
city_radius = 0.2
city_density = 0.6

num_city_points = int(num_points * city_density)
num_rural_points = num_points - num_city_points

city_x_coords = []
city_y_coords = []
for cx, cy in city_centers:
    city_x_coords.extend(np.random.uniform(cx - city_radius, cx + city_radius, num_city_points // len(city_centers)))
    city_y_coords.extend(np.random.uniform(cy - city_radius, cy + city_radius, num_city_points // len(city_centers)))

x_coords = np.concatenate((x_coords[:num_rural_points], city_x_coords))
y_coords = np.concatenate((y_coords[:num_rural_points], city_y_coords))

# get GeoDataFrame
points = gpd.points_from_xy(x_coords, y_coords)
gdf = gpd.GeoDataFrame(geometry=points, crs="EPSG:4326")

# %% [markdown]
# ## Create Spatial Index (r-tree)

# %%
idx = index.Index()

# insert points into the spatial index
for i, geom in enumerate(gdf.geometry):
    idx.insert(i, geom.bounds, obj=i)

# %% [markdown]
# ## Assign leaves to points and get leave bounding boxes

# %%
leaves = idx.leaves()

leaves_bbox = []
for leaf in leaves:
  leaf_idx = leaf[0]
  leaf_point_idxs = leaf[1]
  leaf_bbox = leaf[2]

  # add leaf index to associated points
  gdf.loc[leaf_point_idxs, 'leaf_idx'] = leaf_idx

  # grab the bounding box of leaf node
  leaves_bbox.append(box(*leaf_bbox))

leaves_bbox = gpd.GeoDataFrame(geometry=leaves_bbox, crs="EPSG:4326").reset_index()

# %% [markdown]
# ## Visualise partitioned points and leaf bounding box

# %%
m = gdf.explore(
    column='leaf_idx'
    , tooltip=False
    , tiles='CartoDB dark_matter'

    , width='65%'
    , height='65%'

    , cmap='tab20b'
    , marker_kwds={'radius': 1, 'fillOpacity': 0.6}
    , catergorical=True
)

leaves_bbox.explore(m=m, color='white', style_kwds={'fill': False, 'weight': 2}, tooltip=False)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8e6610031ef4411669ac7f42008bfad3 {
#                     position: relative;
#                     width: 65.0%;
#                     height: 65.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8e6610031ef4411669ac7f42008bfad3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8e6610031ef4411669ac7f42008bfad3 = L.map(
#                 &quot;map_8e6610031ef4411669ac7f42008bfad3&quot;,
#                 {
#                     center: [56.12512696097777, 10.323832532437034],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_8e6610031ef4411669ac7f42008bfad3);
#
#
#
#
#
#             var tile_layer_fdaad119e5b93e662cf061da81eecf2c = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fdaad119e5b93e662cf061da81eecf2c.addTo(map_8e6610031ef4411669ac7f42008bfad3);
#
#
#             map_8e6610031ef4411669ac7f42008bfad3.fitBounds(
#                 [[54.50029772876547, 8.00022365201546], [57.74995619319007, 12.647441412858608]],
#                 {}
#             );
#
#
#         function geo_json_c35906711e0fa208aee77efd5575f35a_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;7&quot;: case &quot;11&quot;: case &quot;25&quot;: case &quot;36&quot;: case &quot;45&quot;: case &quot;47&quot;: case &quot;48&quot;: case &quot;75&quot;: case &quot;81&quot;: case &quot;84&quot;: case &quot;90&quot;: case &quot;96&quot;: case &quot;100&quot;: case &quot;102&quot;: case &quot;117&quot;: case &quot;118&quot;: case &quot;119&quot;: case &quot;121&quot;: case &quot;128&quot;: case &quot;135&quot;: case &quot;162&quot;: case &quot;175&quot;: case &quot;182&quot;: case &quot;185&quot;: case &quot;186&quot;: case &quot;202&quot;: case &quot;204&quot;: case &quot;213&quot;: case &quot;214&quot;: case &quot;226&quot;: case &quot;230&quot;: case &quot;234&quot;: case &quot;235&quot;: case &quot;240&quot;: case &quot;242&quot;: case &quot;256&quot;: case &quot;258&quot;: case &quot;272&quot;: case &quot;273&quot;: case &quot;306&quot;: case &quot;312&quot;: case &quot;319&quot;: case &quot;338&quot;: case &quot;346&quot;: case &quot;348&quot;: case &quot;368&quot;: case &quot;377&quot;: case &quot;379&quot;: case &quot;380&quot;: case &quot;385&quot;: case &quot;400&quot;: case &quot;408&quot;: case &quot;412&quot;: case &quot;427&quot;: case &quot;446&quot;: case &quot;449&quot;: case &quot;452&quot;: case &quot;477&quot;: case &quot;486&quot;: case &quot;507&quot;: case &quot;513&quot;: case &quot;538&quot;: case &quot;540&quot;: case &quot;548&quot;: case &quot;550&quot;: case &quot;555&quot;: case &quot;558&quot;: case &quot;560&quot;: case &quot;561&quot;: case &quot;564&quot;: case &quot;566&quot;: case &quot;570&quot;: case &quot;577&quot;: case &quot;600&quot;: case &quot;601&quot;: case &quot;608&quot;: case &quot;616&quot;: case &quot;623&quot;: case &quot;629&quot;: case &quot;632&quot;: case &quot;640&quot;: case &quot;654&quot;: case &quot;657&quot;: case &quot;690&quot;: case &quot;691&quot;: case &quot;702&quot;: case &quot;716&quot;: case &quot;746&quot;: case &quot;747&quot;: case &quot;748&quot;: case &quot;756&quot;: case &quot;758&quot;: case &quot;759&quot;: case &quot;761&quot;: case &quot;763&quot;: case &quot;764&quot;: case &quot;766&quot;: case &quot;773&quot;: case &quot;776&quot;: case &quot;777&quot;: case &quot;790&quot;: case &quot;793&quot;: case &quot;803&quot;: case &quot;851&quot;: case &quot;859&quot;: case &quot;860&quot;: case &quot;869&quot;: case &quot;878&quot;: case &quot;879&quot;: case &quot;890&quot;: case &quot;926&quot;: case &quot;927&quot;: case &quot;933&quot;: case &quot;936&quot;: case &quot;937&quot;: case &quot;941&quot;: case &quot;946&quot;: case &quot;953&quot;: case &quot;955&quot;: case &quot;959&quot;: case &quot;978&quot;: case &quot;982&quot;: case &quot;993&quot;: case &quot;997&quot;: case &quot;999&quot;: case &quot;1000&quot;: case &quot;1003&quot;: case &quot;1007&quot;: case &quot;1015&quot;: case &quot;1020&quot;: case &quot;1028&quot;: case &quot;1039&quot;: case &quot;1042&quot;: case &quot;1065&quot;: case &quot;1071&quot;: case &quot;1074&quot;: case &quot;1086&quot;: case &quot;1091&quot;: case &quot;1092&quot;: case &quot;1107&quot;: case &quot;1119&quot;: case &quot;1120&quot;: case &quot;1136&quot;: case &quot;1140&quot;: case &quot;1148&quot;: case &quot;1173&quot;: case &quot;1175&quot;: case &quot;1178&quot;: case &quot;1186&quot;: case &quot;1189&quot;: case &quot;1191&quot;: case &quot;1228&quot;: case &quot;1232&quot;: case &quot;1240&quot;: case &quot;1247&quot;: case &quot;1248&quot;: case &quot;1249&quot;: case &quot;1262&quot;: case &quot;1270&quot;:
